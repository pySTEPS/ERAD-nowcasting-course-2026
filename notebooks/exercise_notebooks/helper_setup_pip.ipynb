# %% [markdown]
# This notebook is for setting up pysteps and downloading the example data.

# %%
# !apt-get install -qq libgdal-dev libgeos-dev
# !uv pip install cartopy pyproj netCDF4 xarray pysteps
# Out:
# Found existing installation: Shapely 1.8.4
# Uninstalling Shapely-1.8.4:
#   Successfully uninstalled Shapely-1.8.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shapely
#   Downloading Shapely-1.8.4.tar.gz (199 kB)
#      |████████████████████████████████| 199 kB 23.1 MB/s
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for shapely from https://files.pythonhosted.org/packages/b5/9a/625d4fc91ef85873801a16700840786117df4c016162a4532c998a7fe6bc/Shapely-1.8.4.tar.gz#sha256=a195e51caafa218291f2cbaa3fef69fd3353c93ec4b65b2a4722c4cf40c3198c.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'wheel'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: shapely
#   Building wheel for shapely (PEP 517) ... done
#   Created wheel for shapely: filename=Shapely-1.8.4-cp37-cp37m-linux_x86_64.whl size=669444 sha256=a7ba89f7d459ddbd06f3b35247ef70a02f33ef6102508142bc415b677ba49fba
#   Stored in directory: /root/.cache/pip/wheels/0b/f0/55/139a0ab07fbf91378f9b7062842aee4d4bb3566a1fc30ac7a4
# Successfully built shapely
# Installing collected packages: shapely
# Successfully installed shapely-1.8.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cartopy
#   Downloading Cartopy-0.20.3.tar.gz (10.8 MB)
#      |████████████████████████████████| 10.8 MB 26.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# WARNING: Discarding https://files.pythonhosted.org/packages/98/a9/0e4000eabadfcff6373c0fec790863b543b919cbfec18aed60d71ba67d5d/Cartopy-0.20.3.tar.gz#sha256=0d60fa2e2fbd77c4d1f6b1f9d3b588966147f07c1b179d2d34570ac1e1b49006 (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmp641uh_qs Check the logs for full command output.
#   Downloading Cartopy-0.20.2.tar.gz (10.8 MB)
#      |████████████████████████████████| 10.8 MB 45.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# WARNING: Discarding https://files.pythonhosted.org/packages/f6/55/1e1c737dc9436b320deead73d1c455ddbb74b8b6992081863492f6f6378a/Cartopy-0.20.2.tar.gz#sha256=4d08c198ecaa50a6a6b109d0f14c070e813defc046a83ac5d7ab494f85599e35 (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmp6vl2_bt_ Check the logs for full command output.
#   Downloading Cartopy-0.20.1.tar.gz (10.8 MB)
#      |████████████████████████████████| 10.8 MB 58.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# WARNING: Discarding https://files.pythonhosted.org/packages/fc/59/aa52698e3838f4cd0e7eaa75bd86837e9e0b05041dbdaee3cda2fffced06/Cartopy-0.20.1.tar.gz#sha256=91f87b130e2574547a20cd634498df97d797abd12dcfd0235bc0cdbcec8b05e3 (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpbvh7uehq Check the logs for full command output.
#   Downloading Cartopy-0.20.0.tar.gz (10.8 MB)
#      |████████████████████████████████| 10.8 MB 52.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# WARNING: Discarding https://files.pythonhosted.org/packages/0f/c0/58453b036e79046d211f083880d58dcce787e7e07647ac25dc46c6555099/Cartopy-0.20.0.tar.gz#sha256=eae58aff26806e63cf115b2bce9477cedc4aa9f578c5e477b2c25cfa404f2b7a (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmp4ct0b7pq Check the logs for full command output.
#   Downloading Cartopy-0.19.0.post1.tar.gz (12.1 MB)
#      |████████████████████████████████| 12.1 MB 72.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: shapely>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from cartopy) (1.8.4)
# Collecting pyshp>=2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.5 MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from cartopy) (1.21.6)
# Building wheels for collected packages: cartopy
#   Building wheel for cartopy (PEP 517) ... done
#   Created wheel for cartopy: filename=Cartopy-0.19.0.post1-cp37-cp37m-linux_x86_64.whl size=12516303 sha256=fa59723d2a9f6562cc17f26057f2926d3f6ee0116f012c8d9a08c89c00b01bad
#   Stored in directory: /root/.cache/pip/wheels/98/01/f7/bd10aeb96fe4b518cde5f7c4f5e12c7202f85b7353a5017847
# Successfully built cartopy
# Installing collected packages: pyshp, cartopy
# Successfully installed cartopy-0.19.0.post1 pyshp-2.3.1

# %%
import os
from google.colab import drive
from pysteps.datasets import download_pysteps_data

if not os.path.exists("/content/mnt/MyDrive"):
  drive.mount("mnt")
if not os.path.exists("/content/mnt/MyDrive/Colab Notebooks/pysteps_data"):
  download_pysteps_data("pysteps_data")
# Out:
# Mounted at mnt

# %%
from pysteps.datasets import create_default_pystepsrc
config_file_path = create_default_pystepsrc("pysteps_data")

# %%
import pysteps
_ = pysteps.load_config_file(config_file_path, verbose=True)
# Out:
# Pysteps configuration file found at: /root/.pysteps/pystepsrc
